# %% [markdown]
# # Question 1

# %% [markdown]
# ## What is the most booked neighbourhood in Paris ?

# %% [markdown]
# ### Introduction

# %% [markdown]
# This notebook contains the analysis performed to solve our first question about the **most booked neighbourhood** in **Paris** in **June** 2022.
# The data was collected from [**Inside Airbnb** website](http://insideairbnb.com/get-the-data/).
# Check this section to get the [**listings**](http://data.insideairbnb.com/france/ile-de-france/paris/2022-06-06/data/listings.csv.gz) data, the [**calendar**](http://data.insideairbnb.com/france/ile-de-france/paris/2022-06-06/data/calendar.csv.gz) and also the [**reviews**](http://data.insideairbnb.com/france/ile-de-france/paris/2022-06-06/data/reviews.csv.gz) data provided in **Paris, Île-de-France, France** section.
# This data will be used to answer the questions and complete this analysis about **Paris-Airbnb-data**.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm

# %%
# Reading the data files
listings = pd.read_csv('data/paris-airbnb/listings.csv')
calendar = pd.read_csv('data/paris-airbnb/calendar.csv')

# %%
# Looking into the dataframes
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  26660141  https://www.airbnb.com/rooms/26660141  20220606014139
# 1  25177338  https://www.airbnb.com/rooms/25177338  20220606014139
# 2  25218084  https://www.airbnb.com/rooms/25218084  20220606014139
# 3  23135649  https://www.airbnb.com/rooms/23135649  20220606014139
# 4  23259887  https://www.airbnb.com/rooms/23259887  20220606014139
#
#   last_scraped                                             name  \
# 0   2022-06-07  CHARMANT APPARTEMENT,  50M2 AUX PORTES DE PARIS
# 1   2022-06-07          Cosy and quiet appartement at Les Lilas
# 2   2022-06-07                            paris avec une maison
# 3   2022-06-07         Charming studio, Pont de Neuilly - Paris
# 4   2022-06-07                               A cosy appartement
#
#                                          description  \
# 0  Charmant appartement avec petit balcon filant,...
# 1  <b>The space</b><br />Le logement est situé da...
# 2  une maison restaurée et faite à notre image ap...
# 3  Studio apartment in the heart of the prestigio...
# 4  Situé dans un quartier agréable proche de Chât...
#
#                                neighborhood_overview  \
# 0  La rue principale à la sortie du métro est trè...
# 1                                                NaN
# 2  Être dans un véritable maison avec un parc à q...
# 3  The Saint James district of Neuilly sur Seine ...
# 4                                                NaN
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/a776b332-0fde...  200407698
# 1  https://a0.muscache.com/pictures/e984c1e4-6d40...  185793394
# 2  https://a0.muscache.com/pictures/dbfc69a1-76cb...  190542280
# 3  https://a0.muscache.com/pictures/58399f3d-c271...  171938056
# 4  https://a0.muscache.com/pictures/ad0ade9c-89d5...   20135501
#
#                                       host_url  ...  \
# 0  https://www.airbnb.com/users/show/200407698  ...
# 1  https://www.airbnb.com/users/show/185793394  ...
# 2  https://www.airbnb.com/users/show/190542280  ...
# 3  https://www.airbnb.com/users/show/171938056  ...
# 4   https://www.airbnb.com/users/show/20135501  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   4.88                4.94
# 1                        4.56                   4.50                4.56
# 2                        5.00                   4.50                5.00
# 3                        4.94                   4.87                4.61
# 4                        4.86                   4.91                4.65
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              1
# 2     NaN                f                              1
# 3     NaN                f                              1
# 4     NaN                t                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.38
# 1                                           0              0.35
# 2                                           0              0.05
# 3                                           0              0.65
# 4                                           0              0.87
#
# [5 rows x 74 columns]

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0    26660141  2022-06-07         f  $90.00         $90.00             5.0
# 1    26660141  2022-06-08         f  $90.00         $90.00             5.0
# 2    26660141  2022-06-09         f  $90.00         $90.00             5.0
# 3    26660141  2022-06-10         f  $90.00         $90.00             5.0
# 4    26660141  2022-06-11         f  $90.00         $90.00             5.0
#
#    maximum_nights
# 0             8.0
# 1             8.0
# 2             8.0
# 3             8.0
# 4             8.0

# %%
# Calculating the shapes of dataframes

print('The shape of listings dataframe is:',listings.shape)
print('The shape of calendar dataframe is:',calendar.shape)
# Out:
# The shape of listings dataframe is: (56739, 74)
# The shape of calendar dataframe is: (20707929, 7)

# %%
# Viewing some descriptive statistics about the numerical values of listings dataframe
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  5.673900e+04  5.673900e+04  5.673900e+04         56727.000000
# mean   6.935639e+16  2.022061e+13  1.128384e+08            12.481041
# std    1.922281e+17  2.722680e+01  1.360755e+08            83.879858
# min    5.396000e+03  2.022061e+13  2.626000e+03             0.000000
# 25%    1.369082e+07  2.022061e+13  1.463397e+07             1.000000
# 50%    3.092530e+07  2.022061e+13  4.425650e+07             1.000000
# 75%    4.716712e+07  2.022061e+13  1.767666e+08             2.000000
# max    6.421428e+17  2.022061e+13  4.625783e+08          1246.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               56727.000000                           0.0  56739.000000
# mean                   12.481041                           NaN     48.863462
# std                    83.879858                           NaN      0.020537
# min                     0.000000                           NaN     48.803750
# 25%                     1.000000                           NaN     48.849310
# 50%                     1.000000                           NaN     48.865160
# 75%                     2.000000                           NaN     48.879630
# max                  1246.000000                           NaN     48.913920
#
#           longitude  accommodates  bathrooms  ...  review_scores_cleanliness  \
# count  56739.000000  56739.000000        0.0  ...               44684.000000
# mean       2.343554      3.060135        NaN  ...                   4.593612
# std        0.040348      1.666769        NaN  ...                   0.523597
# min        2.206290      0.000000        NaN  ...                   0.000000
# 25%        2.319836      2.000000        NaN  ...                   4.440000
# 50%        2.347200      2.000000        NaN  ...                   4.750000
# 75%        2.370911      4.000000        NaN  ...                   4.960000
# max        2.487250     16.000000        NaN  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           44673.000000                 44681.000000
# mean                4.793961                     4.804103
# std                 0.402834                     0.401047
# min                 0.000000                     0.000000
# 25%                 4.750000                     4.780000
# 50%                 4.920000                     4.940000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count            44670.000000         44668.000000
# mean                 4.789998             4.608434
# std                  0.353174             0.467024
# min                  0.000000             0.000000
# 25%                  4.730000             4.500000
# 50%                  4.900000             4.710000
# 75%                  5.000000             4.890000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                    56739.000000
# mean                        10.025045
# std                         31.835610
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          2.000000
# max                        233.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 56739.000000
# mean                                      9.264915
# std                                      31.685771
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                     233.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  56739.000000
# mean                                       0.538836
# std                                        3.410858
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       75.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 56739.000000       45281.000000
# mean                                      0.034826           0.980303
# std                                       0.672199           1.541610
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.140000
# 50%                                       0.000000           0.460000
# 75%                                       0.000000           1.220000
# max                                      26.000000          85.170000
#
# [8 rows x 40 columns]

# %% [markdown]
# We can notice for the moment that **neighbourhood_group_cleansed** and **bathrooms** are the columns with the most missing values. We can confirm that by taking a look into the number of missing values per column.

# %%
# View the count of missing values of listings dataframe

listings.isnull().sum().sort_values()
# Out:
# id                                  0
# availability_30                     0
# number_of_reviews                   0
# neighbourhood_cleansed              0
# calendar_last_scraped               0
#                                 ...
# license                         24724
# host_about                      29151
# calendar_updated                56739
# neighbourhood_group_cleansed    56739
# bathrooms                       56739
# Length: 74, dtype: int64

# %% [markdown]
# We can also notice that the **calendar_updated** column is full of missing values.

# %%
# Plot the ratio of missing values with the number of values for the listings dataframe

(listings.isnull().sum()/listings.shape[0]).sort_values(ascending=False)[:10].plot(kind='bar');

# %% [markdown]
# This plot shows the top 10 columns with missing values, we can see that **neighbourhood_group_cleansed**, **bathrooms** and **calendar_updated** come first with 100 % of missing values rate compared to the whole values.

# %%
# Viewing some descriptive statistics about the numerical values of calendar dataframe
calendar.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  2.070793e+07    2.070756e+07    2.070756e+07
# mean   6.936259e+16    8.954375e+01    4.780960e+05
# std    1.922339e+17    1.602215e+02    3.200689e+07
# min    5.396000e+03    1.000000e+00    1.000000e+00
# 25%    1.368675e+07    2.000000e+00    3.000000e+02
# 50%    3.092166e+07    3.000000e+00    1.125000e+03
# 75%    4.716802e+07    3.000000e+01    1.125000e+03
# max    6.421428e+17    9.999000e+03    2.147484e+09

# %% [markdown]
# We can notice that **maxiumum_nights** is the column with the biggest variations of values.

# %%
# View the count of missing values of calendar dataframe
calendar.isnull().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price             173
# adjusted_price    173
# minimum_nights    366
# maximum_nights    366
# dtype: int64

# %%
# Plot the number of missing values with the number of values for the calendar dataframe
(calendar.isnull().sum()).plot(kind='bar');

# %% [markdown]
# We can conclude from the previous figure that there's a small number of missing values in **calendar** dataframe compared to the whole size of the dataframe.

# %%
# Drop the columns that are fully missing from the listings dataframe
listings = listings.dropna(axis=1,how='all')
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  26660141  https://www.airbnb.com/rooms/26660141  20220606014139
# 1  25177338  https://www.airbnb.com/rooms/25177338  20220606014139
# 2  25218084  https://www.airbnb.com/rooms/25218084  20220606014139
# 3  23135649  https://www.airbnb.com/rooms/23135649  20220606014139
# 4  23259887  https://www.airbnb.com/rooms/23259887  20220606014139
#
#   last_scraped                                             name  \
# 0   2022-06-07  CHARMANT APPARTEMENT,  50M2 AUX PORTES DE PARIS
# 1   2022-06-07          Cosy and quiet appartement at Les Lilas
# 2   2022-06-07                            paris avec une maison
# 3   2022-06-07         Charming studio, Pont de Neuilly - Paris
# 4   2022-06-07                               A cosy appartement
#
#                                          description  \
# 0  Charmant appartement avec petit balcon filant,...
# 1  <b>The space</b><br />Le logement est situé da...
# 2  une maison restaurée et faite à notre image ap...
# 3  Studio apartment in the heart of the prestigio...
# 4  Situé dans un quartier agréable proche de Chât...
#
#                                neighborhood_overview  \
# 0  La rue principale à la sortie du métro est trè...
# 1                                                NaN
# 2  Être dans un véritable maison avec un parc à q...
# 3  The Saint James district of Neuilly sur Seine ...
# 4                                                NaN
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/a776b332-0fde...  200407698
# 1  https://a0.muscache.com/pictures/e984c1e4-6d40...  185793394
# 2  https://a0.muscache.com/pictures/dbfc69a1-76cb...  190542280
# 3  https://a0.muscache.com/pictures/58399f3d-c271...  171938056
# 4  https://a0.muscache.com/pictures/ad0ade9c-89d5...   20135501
#
#                                       host_url  ...  \
# 0  https://www.airbnb.com/users/show/200407698  ...
# 1  https://www.airbnb.com/users/show/185793394  ...
# 2  https://www.airbnb.com/users/show/190542280  ...
# 3  https://www.airbnb.com/users/show/171938056  ...
# 4   https://www.airbnb.com/users/show/20135501  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   4.88                4.94
# 1                        4.56                   4.50                4.56
# 2                        5.00                   4.50                5.00
# 3                        4.94                   4.87                4.61
# 4                        4.86                   4.91                4.65
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              1
# 2     NaN                f                              1
# 3     NaN                f                              1
# 4     NaN                t                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.38
# 1                                           0              0.35
# 2                                           0              0.05
# 3                                           0              0.65
# 4                                           0              0.87
#
# [5 rows x 71 columns]

# %% [markdown]
# We dropped the **neighbourhood_group_cleansed**, **bathrooms** and **calendar_updated** columns from the listings dataframe.
#
# Since we are interesting in solving our first question about the **most booked neighbourhoods in Paris**, we are going to work with a slice of the data that doesn't include missing values in the **host_neighbourhood** column.

# %%
listings = listings.dropna(subset=['host_neighbourhood'])
listings.head()
# Out:
#                     id                                      listing_url  \
# 6             26767859            https://www.airbnb.com/rooms/26767859
# 11  595468760998844211  https://www.airbnb.com/rooms/595468760998844211
# 16  553246603210104857  https://www.airbnb.com/rooms/553246603210104857
# 33            35412696            https://www.airbnb.com/rooms/35412696
# 40            36504421            https://www.airbnb.com/rooms/36504421
#
#          scrape_id last_scraped  \
# 6   20220606014139   2022-06-07
# 11  20220606014139   2022-06-06
# 16  20220606014139   2022-06-06
# 33  20220606014139   2022-06-06
# 40  20220606014139   2022-06-06
#
#                                                  name  \
# 6    Private room in a beautiful duplex next to Paris
# 11   ★Duplex for 4p in St Cloud with a large terrace★
# 16  Charmant appt spacieux et paisible - vue sur parc
# 33     Appartement plein de charme au coeur des Puces
# 40  GuestReady - Charming studio in Issy-les-Mouli...
#
#                                           description  \
# 6   Private room in a nice duplex (with two rooms)...
# 11  I will be delighted to welcome you to my charm...
# 16  Location Appartement Meublé à Saint Cloud (92)...
# 33  -In the heart of the Saint Ouen Paris flea mar...
# 40  Located in a quiet residential area, this apar...
#
#                                 neighborhood_overview  \
# 6   10 minutes walk from the Parc de la Villette (...
# 11  ST CLOUD RACECOURSE <br />Situated on a platea...
# 16                                                NaN
# 33                                                NaN
# 40  The parks are numerous in the city, conducive ...
#
#                                           picture_url    host_id  \
# 6   https://a0.muscache.com/pictures/1de4e19a-a452...    7786899
# 11  https://a0.muscache.com/pictures/miso/Hosting-...   50502817
# 16  https://a0.muscache.com/pictures/0be3d219-7495...  434895890
# 33  https://a0.muscache.com/pictures/d3781ee0-8c91...  433304227
# 40  https://a0.muscache.com/pictures/0af527b0-1226...  402191311
#
#                                        host_url  ...  \
# 6     https://www.airbnb.com/users/show/7786899  ...
# 11   https://www.airbnb.com/users/show/50502817  ...
# 16  https://www.airbnb.com/users/show/434895890  ...
# 33  https://www.airbnb.com/users/show/433304227  ...
# 40  https://www.airbnb.com/users/show/402191311  ...
#
#    review_scores_communication review_scores_location review_scores_value  \
# 6                         5.00                   4.00                4.00
# 11                         NaN                    NaN                 NaN
# 16                        4.50                   4.50                4.00
# 33                        4.89                   4.67                4.56
# 40                        4.77                   4.75                4.29
#
#           license instant_bookable calculated_host_listings_count  \
# 6             NaN                f                              3
# 11            NaN                t                            134
# 16            NaN                f                             59
# 33            NaN                f                             17
# 40  9204000014635                t                            204
#
#    calculated_host_listings_count_entire_homes  \
# 6                                            1
# 11                                         133
# 16                                          59
# 33                                          17
# 40                                         203
#
#    calculated_host_listings_count_private_rooms  \
# 6                                             2
# 11                                            1
# 16                                            0
# 33                                            0
# 40                                            0
#
#    calculated_host_listings_count_shared_rooms reviews_per_month
# 6                                            0              0.03
# 11                                           0               NaN
# 16                                           0              0.54
# 33                                           0              0.25
# 40                                           0              1.36
#
# [5 rows x 71 columns]

# %% [markdown]
# ### To answer the first question, we need to merge the two dataframes **listings** and **calendar** to get more insights about the availability of listings.

# %%
# Rename the column listings ID column to match with listing_id in calendar dataframe 
# and also calendar_last_scraped to match the date column of calendar dataframe
listings.rename(columns={"id":'listing_id','calendar_last_scraped':'date'},inplace=True)

# %%
listings.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms_text', 'bedrooms', 'beds',
#        'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'date', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# View the availability options from calendar dataframe
calendar.available.value_counts(dropna=False)
# Out:
# f    14868257
# t     5839672
# Name: available, dtype: int64

# %% [markdown]
# We have a binary availability options **t** for True which means available listing and **f** for False that means booked listing.

# %%
# Select the booked listings
booked_listings = calendar.loc[calendar.available=='f']
booked_listings.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0    26660141  2022-06-07         f  $90.00         $90.00             5.0
# 1    26660141  2022-06-08         f  $90.00         $90.00             5.0
# 2    26660141  2022-06-09         f  $90.00         $90.00             5.0
# 3    26660141  2022-06-10         f  $90.00         $90.00             5.0
# 4    26660141  2022-06-11         f  $90.00         $90.00             5.0
#
#    maximum_nights
# 0             8.0
# 1             8.0
# 2             8.0
# 3             8.0
# 4             8.0

# %%
# Merge booked listings with listings with a host_location and host_neighbourhood 
merged_df = pd.merge(booked_listings,listings,on=['listing_id','date','minimum_nights','maximum_nights'],how='inner')
merged_df
# Out:
#                listing_id        date available  price_x adjusted_price  \
# 0                35412696  2022-06-06         f  $110.00        $110.00
# 1                26767859  2022-06-07         f   $18.00         $18.00
# 2      623628739025164042  2022-06-06         f  $120.00         $96.00
# 3      595468760998844211  2022-06-06         f  $370.00        $246.00
# 4                46324536  2022-06-06         f  $128.00        $128.00
# ...                   ...         ...       ...      ...            ...
# 27050  639603227312425701  2022-06-06         f   $90.00         $90.00
# 27051  639637839235596859  2022-06-06         f   $80.00         $80.00
# 27052  639686450077893784  2022-06-06         f  $340.00        $289.00
# 27053  552672579134310886  2022-06-06         f   $80.00         $80.00
# 27054             4705066  2022-06-06         f   $22.00         $22.00
#
#        minimum_nights  maximum_nights  \
# 0                 2.0          1125.0
# 1                 2.0          1125.0
# 2                 3.0          1125.0
# 3                 3.0           365.0
# 4                30.0          1125.0
# ...               ...             ...
# 27050            30.0           365.0
# 27051             2.0           365.0
# 27052             7.0            20.0
# 27053             3.0           365.0
# 27054            28.0           365.0
#
#                                            listing_url       scrape_id  \
# 0                https://www.airbnb.com/rooms/35412696  20220606014139
# 1                https://www.airbnb.com/rooms/26767859  20220606014139
# 2      https://www.airbnb.com/rooms/623628739025164042  20220606014139
# 3      https://www.airbnb.com/rooms/595468760998844211  20220606014139
# 4                https://www.airbnb.com/rooms/46324536  20220606014139
# ...                                                ...             ...
# 27050  https://www.airbnb.com/rooms/639603227312425701  20220606014139
# 27051  https://www.airbnb.com/rooms/639637839235596859  20220606014139
# 27052  https://www.airbnb.com/rooms/639686450077893784  20220606014139
# 27053  https://www.airbnb.com/rooms/552672579134310886  20220606014139
# 27054             https://www.airbnb.com/rooms/4705066  20220606014139
#
#       last_scraped  ... review_scores_communication review_scores_location  \
# 0       2022-06-06  ...                        4.89                   4.67
# 1       2022-06-07  ...                        5.00                   4.00
# 2       2022-06-06  ...                        5.00                   4.00
# 3       2022-06-06  ...                         NaN                    NaN
# 4       2022-06-06  ...                         NaN                    NaN
# ...            ...  ...                         ...                    ...
# 27050   2022-06-06  ...                         NaN                    NaN
# 27051   2022-06-06  ...                         NaN                    NaN
# 27052   2022-06-06  ...                         NaN                    NaN
# 27053   2022-06-06  ...                        4.75                   4.00
# 27054   2022-06-06  ...                         NaN                    NaN
#
#       review_scores_value                                            license  \
# 0                    4.56                                                NaN
# 1                    4.00                                                NaN
# 2                    5.00                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ...                   ...                                                ...
# 27050                 NaN  Available with a mobility lease only ("bail mo...
# 27051                 NaN                                      7568380131567
# 27052                 NaN                                      7510206652944
# 27053                4.75                                                NaN
# 27054                 NaN                                                NaN
#
#        instant_bookable calculated_host_listings_count  \
# 0                     f                             17
# 1                     f                              3
# 2                     t                             72
# 3                     t                            134
# 4                     f                              6
# ...                 ...                            ...
# 27050                 t                              2
# 27051                 t                             13
# 27052                 f                              2
# 27053                 t                             36
# 27054                 f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                              17
# 1                                               1
# 2                                              72
# 3                                             133
# 4                                               5
# ...                                           ...
# 27050                                           2
# 27051                                          13
# 27052                                           2
# 27053                                          35
# 27054                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                0
# 3                                                1
# 4                                                1
# ...                                            ...
# 27050                                            0
# 27051                                            0
# 27052                                            0
# 27053                                            1
# 27054                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.25
# 1                                               0              0.03
# 2                                               0              1.00
# 3                                               0               NaN
# 4                                               0               NaN
# ...                                           ...               ...
# 27050                                           0               NaN
# 27051                                           0               NaN
# 27052                                           0               NaN
# 27053                                           0              1.30
# 27054                                           0               NaN
#
# [27055 rows x 74 columns]

# %%
merged_df.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price_x', 'adjusted_price',
#        'minimum_nights', 'maximum_nights', 'listing_url', 'scrape_id',
#        'last_scraped', 'name', 'description', 'neighborhood_overview',
#        'picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'beds', 'amenities', 'price_y', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'license',
#        'instant_bookable', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# We noticed that the **price** column was expanded into two new columns **price_x** and **price_y** after merging.
#
# Let's take a look at their values:

# %%
(merged_df.price_x == merged_df.price_x).value_counts(dropna=False)
# Out:
# True    27055
# Name: price_x, dtype: int64

# %% [markdown]
# Both columns have the same values so we can keep the first column safely and drop the other.

# %%
merged_df.drop(columns=['price_y'],inplace=True)

# %%
merged_df.rename(columns={'price_x':'price'},inplace=True)

# %%
merged_df.head()
# Out:
#            listing_id        date available    price adjusted_price  \
# 0            35412696  2022-06-06         f  $110.00        $110.00
# 1            26767859  2022-06-07         f   $18.00         $18.00
# 2  623628739025164042  2022-06-06         f  $120.00         $96.00
# 3  595468760998844211  2022-06-06         f  $370.00        $246.00
# 4            46324536  2022-06-06         f  $128.00        $128.00
#
#    minimum_nights  maximum_nights  \
# 0             2.0          1125.0
# 1             2.0          1125.0
# 2             3.0          1125.0
# 3             3.0           365.0
# 4            30.0          1125.0
#
#                                        listing_url       scrape_id  \
# 0            https://www.airbnb.com/rooms/35412696  20220606014139
# 1            https://www.airbnb.com/rooms/26767859  20220606014139
# 2  https://www.airbnb.com/rooms/623628739025164042  20220606014139
# 3  https://www.airbnb.com/rooms/595468760998844211  20220606014139
# 4            https://www.airbnb.com/rooms/46324536  20220606014139
#
#   last_scraped  ... review_scores_communication review_scores_location  \
# 0   2022-06-06  ...                        4.89                   4.67
# 1   2022-06-07  ...                        5.00                   4.00
# 2   2022-06-06  ...                        5.00                   4.00
# 3   2022-06-06  ...                         NaN                    NaN
# 4   2022-06-06  ...                         NaN                    NaN
#
#   review_scores_value license  instant_bookable  \
# 0                4.56     NaN                 f
# 1                4.00     NaN                 f
# 2                5.00     NaN                 t
# 3                 NaN     NaN                 t
# 4                 NaN     NaN                 f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                             17                                          17
# 1                              3                                           1
# 2                             72                                          72
# 3                            134                                         133
# 4                              6                                           5
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.25
# 1                                           0              0.03
# 2                                           0              1.00
# 3                                           0               NaN
# 4                                           0               NaN
#
# [5 rows x 73 columns]

# %%
# Look into the date range of the bookings
print('The starting date of the bookings is:',merged_df.date.min())
print('The end date of the bookings is:',merged_df.date.max())
# Out:
# The starting date of the bookings is: 2022-06-06
# The end date of the bookings is: 2022-06-07

# %% [markdown]
# And now we have the merged dataframe, we're going to be interested in the **host_neighbourhood** column to find out which are the neighbourhoods the most booked in Paris.

# %%
# Take a look at the host_neighbourhood values
neighbourhoods = merged_df['host_neighbourhood']
top_10 = neighbourhoods.sort_values(ascending=False).value_counts(dropna=False)[:10]
top_10
# Out:
# Montmartre                      1739
# Buttes-Chaumont - Belleville    1448
# Le Marais                       1432
# République                      1405
# XI Arrondissement               1043
# Bastille                        1043
# Batignolles                     1038
# Alésia                           849
# Gare du Nord - Gare de I'Est     805
# Père Lachaise - Ménilmontant     799
# Name: host_neighbourhood, dtype: int64

# %%
# Plot the top 10 most booked neighbourhoods in Paris 
top_10.plot(kind='bar');

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We can see that **Montmartre**, **Buttes-Chaumont - Belleville** and **Le Marais** are the most booked neighbourhoods in Paris between **2022-06-06** and **2022-06-07**.
